# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.preprocessing import preprocess_data

# %%
df = preprocess_data("../data/raw/inventory_data.csv")

df.head()
# Out:
#    Product_Name  Category  Units_Sold  Inventory_Level    Price  Promotion  \
# 0            14         2          41               96   780.63          1
# 1            19         0          22              495  1521.17          1
# 2            17         0          46              199   485.75          1
# 3             1         1          25              464  1042.25          1
# 4             5         2          42              293   939.73          1
#
#    Supplier  Lead_Time   Revenue  Year  Month  Day  Day_of_Week
# 0         3         12  32005.83  2023      3    7            1
# 1         0          4  33465.74  2023      1   29            6
# 2         0          3  22344.50  2024      4   28            6
# 3         4         14  26056.25  2023     10   20            4
# 4         3          5  39468.66  2023      4   19            2

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product_Name     10000 non-null  int64
#  1   Category         10000 non-null  int64
#  2   Units_Sold       10000 non-null  int64
#  3   Inventory_Level  10000 non-null  int64
#  4   Price            10000 non-null  float64
#  5   Promotion        10000 non-null  int64
#  6   Supplier         10000 non-null  int64
#  7   Lead_Time        10000 non-null  int64
#  8   Revenue          10000 non-null  float64
#  9   Year             10000 non-null  int32
#  10  Month            10000 non-null  int32
#  11  Day              10000 non-null  int32
#  12  Day_of_Week      10000 non-null  int32
# dtypes: float64(2), int32(4), int64(7)
# memory usage: 859.5 KB
